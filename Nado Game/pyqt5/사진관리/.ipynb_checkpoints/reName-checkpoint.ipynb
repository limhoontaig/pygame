# %%
import os
import re
import pathlib
import stat
from datetime import datetime
from PIL import Image
from PIL.ExifTags import TAGS
from time import time
import time

#path = 'E:\\source\\pygame\\Nado Game\\pyqt5\\사진관리\\data'
path = 'C:\\사진\\2006년\\2006년01월\\2006년01월16일 채혁입대'
file = '20060116_132458_DSCF2972.JPG'


def takePictureTime(path, f):
    print (path, f)
    filename = pathlib.Path(path, f)
    print(filename)
    #try :
    with Image.open(filename) as im:
        info = im._getexif()
    # 새로운 딕셔너리 생성
    taglabel = {}
    for tag, value in info.items():
        decoded = TAGS.get(tag, tag)
        taglabel[decoded] = value
    #print(f, taglabel)
    try:
        s = taglabel['DateTimeOriginal']
        print(f, ' DateTimeOriginal: ',s)
        timestamp = time.mktime(datetime.strptime(s, '%Y:%m:%d %H:%M:%S').timetuple())
        print(timestamp)
        return timestamp
    except:
        print(taglabel)

head, tail = os.path.split(path)
print(head, tail)
baseName = os.path.basename(path)
checker = re.compile(r'^(19\d\d|20\d\d)[년\-_. ]?(0[1-9]|1[012])[월\-_. ]?(0[1-9]|[12][0-9]|3[01])[일]?')
dir = checker.match(baseName)
if len(str(dir)) > dir.end():
    remark = baseName[dir.end():]
print(dir, remark)
print(dir.span(), dir.string)

    

#except:
#    now = datetime.now()
#    timestamp = datetime.timestamp(now)
#return timestamp
#file = 'BNPP 1N2 Excavation ceremony Recovered_Oct_01_2011_090.JPG'
#print(takePictureTime(path, file))

# %%
#path = 'E:\\source\\pygame\\Nado Game\\pyqt5\\사진관리\\data'
path = 'D:\\사진\\20년\\20년11월\\20년11월09일 BNPP 1N2 Excavation ceremony'

def takePictureTime(path, f):
    print (path, f)
    filename, fileExtension = os.path.splitext(f)
    print(fileExtension)
    if fileExtension != ('.JPG'):
        print(f, f, f)
        return
    else:
        filename = pathlib.Path(path, f)
        #try :
        with Image.open(filename) as im:
            info = im._getexif()
        # 새로운 딕셔너리 생성
        taglabel = {}
        for tag, value in info.items():
            decoded = TAGS.get(tag, tag)
            taglabel[decoded] = value
        #print(f, taglabel)
        try:
            s = taglabel['DateTimeOriginal']
            print(f, ' DateTimeOriginal: ',s)
            timestamp = time.mktime(datetime.strptime(s, '%Y:%m:%d %H:%M:%S').timetuple())
            return timestamp
        except:
            print(taglabel)
            return taglabel


        
        
    #except:
    #    now = datetime.now()
    #    timestamp = datetime.timestamp(now)
    #return timestamp


files = os.listdir(path)
for file in files:
    print(takePictureTime(path, file))
    if takePictureTime(path, file):
        min_time = takePictureTime(path, file)
    else:        
        f = pathlib.Path(path, file)
        T = os.stat(f)
        D_time = takePictureTime(path, file)
        c_time = T.st_ctime
        m_time = T.st_mtime
        a_time = T.st_atime
        min_time = min(c_time, m_time, a_time)#, D_time)
        print('min_time: ', min_time, 'D_time: ', D_time)
        #if min_time < D_time:
        #    print('min_time: ', min_time, 'D_time: ', D_time)
    
    print(min_time)
    dt = datetime.fromtimestamp(min_time)
    y = dt.strftime("%Y%m%d_%H%M%S")
    new_f = y+'_'+file
    print(y, file, new_f)
    

text = ['891031', '1923-12-11 전주']
checker = re.compile(r'^(19\d\d|20\d\d|\d\d)[년\-_. ]?(0[1-9]|1[012])[월\-_. ]?(0[1-9]|[12][0-9]|3[01])[일]?')
for t in text:
    D = checker.search(t)
    if D:
        print(D.end())
    else:
        print('None')

# %%
import sys
from PyQt5.QtWidgets import *
from PyQt5.QtCore import Qt
from PyQt5.QtCore import QThread
import time
    
class MyThread(QThread):
    cnt=0

    def __init__(self):
        super().__init__()
        
    
    def thread_Other(self):
        for i in range(30):
            print("다른 함수 실행")
            time.sleep(0.01)

    def run(self):
        for i in range (3000):
            self.cnt=self.cnt+1
            print("running %d" %self.cnt)
            time.sleep(0.001)


class MyWindow(QMainWindow):
         
    def __init__(self):
        super().__init__()
        self.setWindowTitle("PyStock")
        self.setGeometry(1000, 200, 300, 300)

        #버튼 정의
        btnRun = QPushButton("다른 메소드 실행", self)	# 버튼 텍스트
        btnRun.move(20, 20)	# 버튼 위치
        btnRun.clicked.connect(self.btn_clicked_1)	# 클릭 시 실행할     

        self.Thread1 = MyThread()
        self.Thread1.start()
     
    def btn_clicked_1(self):
            self.Thread1.thread_Other()
    


if __name__ == "__main__":
    app = QApplication(sys.argv)
    myWindow = MyWindow()
    myWindow.show()

    app.exec_()

# %%
import os
os.path.isfile('C:\\사진정리\\2022년\\2022년07월\\2022년07월24일\\20220724_102612.png')
